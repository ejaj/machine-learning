# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, StratifiedKFold
from sklearn import metrics

from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import RandomForestClassifier
seed = 2017

# %%
# read the data in
df = pd.read_csv("data/Diabetes.csv")
X = df.iloc[:,:8].values     # independent variables
y = df['class'].values     # dependent variables

# %%
#Normalize
X = StandardScaler().fit_transform(X)

# evaluate the model by splitting into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
num_trees = 100
clf_rf = RandomForestClassifier(random_state=seed).fit(X_train, y_train)

# %%
rf_params = {
    'n_estimators': [100, 250, 500, 750, 1000],
    'criterion':  ['gini', 'entropy'],
    'max_features': [None, 'auto', 'sqrt', 'log2'],
    'max_depth': [1, 3, 5, 7, 9]
}

# setting verbose = 10 will print the progress for every 10 task completion
grid = GridSearchCV(clf_rf, rf_params, scoring='roc_auc', cv=kfold, verbose=10, n_jobs=-1)
grid.fit(X_train, y_train)

print ('Best Parameters: ', grid.best_params_)

results = cross_val_score(grid.best_estimator_, X_train,y_train, cv=kfold)
print ("Accuracy - Train CV: ", results.mean())
print ("Accuracy - Train : ", metrics.accuracy_score(grid.best_estimator_.predict(X_train), y_train))
print ("Accuracy - Test : ", metrics.accuracy_score(grid.best_estimator_.predict(X_test), y_test))
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [CV 2/5; 156/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=100;, score=0.815 total time=   0.2s
# [CV 3/5; 156/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=100
# [CV 3/5; 156/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=100;, score=0.819 total time=   0.2s
# [CV 1/5; 157/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=250
# [CV 1/5; 157/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=250;, score=0.847 total time=   0.5s
# [CV 2/5; 159/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=750
# [CV 2/5; 159/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=750;, score=0.817 total time=   1.3s
# [CV 3/5; 163/200] START criterion=entropy, max_depth=7, max_features=None, n_estimators=500
# [CV 3/5; 163/200] END criterion=entropy, max_depth=7, max_features=None, n_estimators=500;, score=0.810 total time=   1.3s
# [CV 3/5; 172/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=250
# [CV 3/5; 172/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=250;, score=0.819 total time=   0.4s
# [CV 4/5; 173/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=500
# [CV 4/5; 173/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=500;, score=0.852 total time=   0.9s
# [CV 4/5; 178/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=500
# [CV 4/5; 178/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=500;, score=0.850 total time=   1.0s
# [CV 5/5; 178/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=500
# [CV 5/5; 178/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=500;, score=0.772 total time=   1.0s
# [CV 4/5; 184/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=750
# [CV 4/5; 184/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=750;, score=0.854 total time=   2.2s
# [CV 5/5; 184/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=750
# [CV 5/5; 184/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=750;, score=0.774 total time=   2.1s
# [CV 4/5; 199/200] START criterion=entropy, max_depth=9, max_features=log2, n_estimators=750
# [CV 4/5; 199/200] END criterion=entropy, max_depth=9, max_features=log2, n_estimators=750;, score=0.850 total time=   1.4s
# [CV 4/5; 2/200] START criterion=gini, max_depth=1, max_features=None, n_estimators=250
# [CV 4/5; 2/200] END criterion=gini, max_depth=1, max_features=None, n_estimators=250;, score=0.762 total time=   0.4s
# [CV 1/5; 6/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=100
# [CV 1/5; 6/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5; 6/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=100
# [CV 2/5; 6/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5; 6/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=100
# [CV 3/5; 6/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5; 6/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=100
# [CV 4/5; 6/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5; 6/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=100
# [CV 5/5; 6/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5; 7/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=250
# [CV 1/5; 7/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 2/5; 7/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=250
# [CV 2/5; 7/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 3/5; 7/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=250
# [CV 3/5; 7/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 4/5; 7/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=250
# [CV 4/5; 7/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 5/5; 7/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=250
# [CV 5/5; 7/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 1/5; 8/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=500
# [CV 1/5; 8/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 2/5; 8/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=500
# [CV 2/5; 8/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 3/5; 8/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=500
# [CV 3/5; 8/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 4/5; 8/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=500
# [CV 4/5; 8/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 5/5; 8/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=500
# [CV 5/5; 8/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 1/5; 9/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=750
# [CV 1/5; 9/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 2/5; 9/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=750
# [CV 2/5; 9/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 3/5; 9/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=750
# [CV 3/5; 9/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 4/5; 9/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=750
# [CV 4/5; 9/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 5/5; 9/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=750
# [CV 5/5; 9/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 1/5; 10/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=1000
# [CV 1/5; 10/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 2/5; 10/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=1000
# [CV 2/5; 10/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 3/5; 10/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=1000
# [CV 3/5; 10/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 4/5; 10/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=1000
# [CV 4/5; 10/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 5/5; 10/200] START criterion=gini, max_depth=1, max_features=auto, n_estimators=1000
# [CV 5/5; 10/200] END criterion=gini, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 1/5; 11/200] START criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100
# [CV 1/5; 11/200] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.847 total time=   0.1s
# [CV 2/5; 11/200] START criterion=gini, max_depth=1, max_features=sqrt, n_estimators=100
# [CV 4/5; 44/200] END criterion=gini, max_depth=5, max_features=None, n_estimators=750;, score=0.846 total time=   1.6s
# [CV 5/5; 54/200] START criterion=gini, max_depth=5, max_features=sqrt, n_estimators=750
# [CV 5/5; 54/200] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=750;, score=0.761 total time=   1.3s
# [CV 3/5; 61/200] START criterion=gini, max_depth=7, max_features=None, n_estimators=100
# [CV 3/5; 61/200] END criterion=gini, max_depth=7, max_features=None, n_estimators=100;, score=0.778 total time=   0.3s
# [CV 4/5; 61/200] START criterion=gini, max_depth=7, max_features=None, n_estimators=100
# [CV 4/5; 61/200] END criterion=gini, max_depth=7, max_features=None, n_estimators=100;, score=0.855 total time=   0.3s
# [CV 5/5; 63/200] START criterion=gini, max_depth=7, max_features=None, n_estimators=500
# [CV 5/5; 63/200] END criterion=gini, max_depth=7, max_features=None, n_estimators=500;, score=0.768 total time=   1.3s
# [CV 1/5; 64/200] START criterion=gini, max_depth=7, max_features=None, n_estimators=750
# [CV 1/5; 64/200] END criterion=gini, max_depth=7, max_features=None, n_estimators=750;, score=0.842 total time=   1.9s
# [CV 5/5; 75/200] START criterion=gini, max_depth=7, max_features=sqrt, n_estimators=1000
# [CV 5/5; 75/200] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=1000;, score=0.769 total time=   1.7s
# [CV 4/5; 80/200] START criterion=gini, max_depth=7, max_features=log2, n_estimators=1000
# [CV 4/5; 80/200] END criterion=gini, max_depth=7, max_features=log2, n_estimators=1000;, score=0.854 total time=   1.8s
# [CV 4/5; 85/200] START criterion=gini, max_depth=9, max_features=None, n_estimators=1000
# [CV 4/5; 85/200] END criterion=gini, max_depth=9, max_features=None, n_estimators=1000;, score=0.847 total time=   2.6s
# [CV 1/5; 101/200] START criterion=entropy, max_depth=1, max_features=None, n_estimators=100
# [CV 1/5; 101/200] END criterion=entropy, max_depth=1, max_features=None, n_estimators=100;, score=0.842 total time=   0.2s
# [CV 2/5; 101/200] START criterion=entropy, max_depth=1, max_features=None, n_estimators=100
# [CV 2/5; 101/200] END criterion=entropy, max_depth=1, max_features=None, n_estimators=100;, score=0.806 total time=   0.2s
# [CV 3/5; 101/200] START criterion=entropy, max_depth=1, max_features=None, n_estimators=100
# [CV 3/5; 101/200] END criterion=entropy, max_depth=1, max_features=None, n_estimators=100;, score=0.786 total time=   0.2s
# [CV 4/5; 101/200] START criterion=entropy, max_depth=1, max_features=None, n_estimators=100
# [CV 4/5; 101/200] END criterion=entropy, max_depth=1, max_features=None, n_estimators=100;, score=0.759 total time=   0.2s
# [CV 3/5; 103/200] START criterion=entropy, max_depth=1, max_features=None, n_estimators=500
# [CV 3/5; 103/200] END criterion=entropy, max_depth=1, max_features=None, n_estimators=500;, score=0.777 total time=   0.8s
# [CV 4/5; 103/200] START criterion=entropy, max_depth=1, max_features=None, n_estimators=500
# [CV 4/5; 103/200] END criterion=entropy, max_depth=1, max_features=None, n_estimators=500;, score=0.765 total time=   0.8s
# [CV 5/5; 113/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=500
# [CV 5/5; 113/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=500;, score=0.736 total time=   0.7s
# [CV 1/5; 114/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=750
# [CV 1/5; 114/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=750;, score=0.855 total time=   1.1s
# [CV 1/5; 121/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=100
# [CV 1/5; 121/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=100;, score=0.861 total time=   0.2s
# [CV 2/5; 121/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=100
# [CV 2/5; 121/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=100;, score=0.814 total time=   0.2s
# [CV 1/5; 123/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=500
# [CV 1/5; 123/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=500;, score=0.862 total time=   1.0s
# [CV 1/5; 125/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=1000
# [CV 1/5; 125/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=1000;, score=0.862 total time=   2.0s
# [CV 1/5; 137/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=250
# [CV 1/5; 137/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=250;, score=0.861 total time=   0.4s
# [CV 2/5; 137/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=250
# [CV 2/5; 137/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=250;, score=0.815 total time=   0.4s
# [CV 5/5; 141/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=100
# [CV 5/5; 141/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=100;, score=0.771 total time=   0.2s
# [CV 4/5; 142/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=250
# [CV 4/5; 142/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=250;, score=0.851 total time=   0.6s
# [CV 2/5; 144/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=750
# [CV 2/5; 144/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=750;, score=0.815 total time=   1.8s
# [CV 2/5; 153/200] START criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500
# [CV 2/5; 153/200] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500;, score=0.811 total time=   0.9s
# [CV 4/5; 155/200] START criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=1000
# [CV 4/5; 155/200] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=1000;, score=0.854 total time=   1.7s
# [CV 3/5; 161/200] START criterion=entropy, max_depth=7, max_features=None, n_estimators=100
# [CV 3/5; 161/200] END criterion=entropy, max_depth=7, max_features=None, n_estimators=100;, score=0.803 total time=   0.3s
# [CV 5/5; 162/200] START criterion=entropy, max_depth=7, max_features=None, n_estimators=250
# [CV 5/5; 162/200] END criterion=entropy, max_depth=7, max_features=None, n_estimators=250;, score=0.772 total time=   0.7s
# [CV 1/5; 165/200] START criterion=entropy, max_depth=7, max_features=None, n_estimators=1000
# [CV 1/5; 165/200] END criterion=entropy, max_depth=7, max_features=None, n_estimators=1000;, score=0.848 total time=   2.7s
# [CV 1/5; 179/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=750
# [CV 1/5; 179/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=750;, score=0.850 total time=   1.5s
# [CV 2/5; 179/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=750
# [CV 2/5; 179/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=750;, score=0.814 total time=   1.4s
# [CV 2/5; 192/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250
# [CV 2/5; 192/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250;, score=0.806 total time=   0.5s
# [CV 3/5; 192/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250
# [CV 3/5; 192/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250;, score=0.808 total time=   0.4s
# [CV 5/5; 193/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=500
# [CV 5/5; 193/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=500;, score=0.778 total time=   0.9s
# [CV 5/5; 195/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=1000
# [CV 5/5; 195/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=1000;, score=0.777 total time=   1.8s
# [CV 1/5; 1/200] START criterion=gini, max_depth=1, max_features=None, n_estimators=100
# [CV 1/5; 1/200] END criterion=gini, max_depth=1, max_features=None, n_estimators=100;, score=0.825 total time=   0.1s
# [CV 2/5; 4/200] START criterion=gini, max_depth=1, max_features=None, n_estimators=750
# [CV 1/5; 146/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5; 146/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=100
# [CV 2/5; 146/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5; 146/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=100
# [CV 3/5; 146/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5; 146/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=100
# [CV 4/5; 146/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5; 146/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=100
# [CV 5/5; 146/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5; 147/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=250
# [CV 1/5; 147/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 2/5; 147/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=250
# [CV 2/5; 147/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 3/5; 147/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=250
# [CV 3/5; 147/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 4/5; 147/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=250
# [CV 4/5; 147/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 5/5; 147/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=250
# [CV 5/5; 147/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 1/5; 148/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=500
# [CV 1/5; 148/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 2/5; 148/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=500
# [CV 2/5; 148/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 3/5; 148/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=500
# [CV 3/5; 148/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 5/5; 148/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=500
# [CV 5/5; 148/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 2/5; 149/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=750
# [CV 2/5; 149/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 4/5; 149/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=750
# [CV 4/5; 149/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 1/5; 150/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=1000
# [CV 1/5; 150/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 4/5; 150/200] START criterion=entropy, max_depth=5, max_features=auto, n_estimators=1000
# [CV 4/5; 150/200] END criterion=entropy, max_depth=5, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 1/5; 151/200] START criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100
# [CV 1/5; 151/200] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.840 total time=   0.2s
# [CV 5/5; 151/200] START criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100
# [CV 5/5; 151/200] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=100;, score=0.768 total time=   0.2s
# [CV 3/5; 152/200] START criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=250
# [CV 3/5; 152/200] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=250;, score=0.807 total time=   0.4s
# [CV 5/5; 153/200] START criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500
# [CV 5/5; 153/200] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500;, score=0.765 total time=   0.8s
# [CV 5/5; 155/200] START criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=1000
# [CV 5/5; 155/200] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=1000;, score=0.769 total time=   1.7s
# [CV 1/5; 162/200] START criterion=entropy, max_depth=7, max_features=None, n_estimators=250
# [CV 1/5; 162/200] END criterion=entropy, max_depth=7, max_features=None, n_estimators=250;, score=0.848 total time=   0.7s
# [CV 4/5; 163/200] START criterion=entropy, max_depth=7, max_features=None, n_estimators=500
# [CV 4/5; 163/200] END criterion=entropy, max_depth=7, max_features=None, n_estimators=500;, score=0.856 total time=   1.3s
# [CV 2/5; 172/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=250
# [CV 2/5; 172/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=250;, score=0.808 total time=   0.4s
# [CV 3/5; 173/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=500
# [CV 3/5; 173/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=500;, score=0.817 total time=   0.9s
# [CV 5/5; 177/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=250
# [CV 5/5; 177/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=250;, score=0.769 total time=   0.5s
# [CV 1/5; 178/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=500
# [CV 1/5; 178/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=500;, score=0.853 total time=   1.0s
# [CV 2/5; 182/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=250
# [CV 2/5; 182/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=250;, score=0.800 total time=   0.7s
# [CV 3/5; 182/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=250
# [CV 3/5; 182/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=250;, score=0.805 total time=   0.7s
# [CV 5/5; 185/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=1000
# [CV 5/5; 185/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=1000;, score=0.770 total time=   2.8s
# [CV 1/5; 186/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=100
# [CV 1/5; 186/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5; 196/200] START criterion=entropy, max_depth=9, max_features=log2, n_estimators=100
# [CV 5/5; 196/200] END criterion=entropy, max_depth=9, max_features=log2, n_estimators=100;, score=0.782 total time=   0.2s
# [CV 2/5; 198/200] START criterion=entropy, max_depth=9, max_features=log2, n_estimators=500
# [CV 2/5; 198/200] END criterion=entropy, max_depth=9, max_features=log2, n_estimators=500;, score=0.811 total time=   1.0s
# [CV 5/5; 200/200] START criterion=entropy, max_depth=9, max_features=log2, n_estimators=1000
# [CV 5/5; 200/200] END criterion=entropy, max_depth=9, max_features=log2, n_estimators=1000;, score=0.775 total time=   1.3s
# [CV 2/5; 3/200] START criterion=gini, max_depth=1, max_features=None, n_estimators=500
# [CV 2/5; 3/200] END criterion=gini, max_depth=1, max_features=None, n_estimators=500;, score=0.799 total time=   0.7s
# [CV 2/5; 12/200] START criterion=gini, max_depth=1, max_features=sqrt, n_estimators=250
# [CV 2/5; 12/200] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=250;, score=0.798 total time=   0.3s
# [CV 3/5; 12/200] START criterion=gini, max_depth=1, max_features=sqrt, n_estimators=250
# [CV 5/5; 109/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 1/5; 110/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000
# [CV 1/5; 110/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 2/5; 110/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000
# [CV 2/5; 110/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 3/5; 110/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000
# [CV 3/5; 110/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 4/5; 110/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000
# [CV 4/5; 110/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 5/5; 110/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000
# [CV 5/5; 110/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 1/5; 111/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=100
# [CV 1/5; 111/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.842 total time=   0.1s
# [CV 2/5; 111/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=100
# [CV 2/5; 111/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.783 total time=   0.1s
# [CV 2/5; 112/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=250
# [CV 2/5; 112/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=250;, score=0.790 total time=   0.3s
# [CV 3/5; 112/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=250
# [CV 3/5; 112/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=250;, score=0.786 total time=   0.3s
# [CV 2/5; 114/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=750
# [CV 2/5; 114/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=750;, score=0.790 total time=   1.1s
# [CV 3/5; 114/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=750
# [CV 3/5; 114/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=750;, score=0.789 total time=   1.1s
# [CV 5/5; 122/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=250
# [CV 5/5; 122/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=250;, score=0.764 total time=   0.5s
# [CV 2/5; 124/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=750
# [CV 2/5; 124/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=750;, score=0.818 total time=   1.5s
# [CV 1/5; 133/200] START criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=500
# [CV 1/5; 133/200] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=500;, score=0.859 total time=   0.8s
# [CV 2/5; 135/200] START criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=1000
# [CV 2/5; 135/200] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=1000;, score=0.802 total time=   1.5s
# [CV 1/5; 143/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=500
# [CV 1/5; 143/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=500;, score=0.857 total time=   1.2s
# [CV 1/5; 145/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=1000
# [CV 1/5; 145/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=1000;, score=0.857 total time=   2.4s
# [CV 4/5; 156/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=100
# [CV 4/5; 156/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=100;, score=0.859 total time=   0.2s
# [CV 4/5; 157/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=250
# [CV 4/5; 157/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=250;, score=0.855 total time=   0.5s
# [CV 5/5; 159/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=750
# [CV 5/5; 159/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=750;, score=0.773 total time=   1.4s
# [CV 2/5; 164/200] START criterion=entropy, max_depth=7, max_features=None, n_estimators=750
# [CV 2/5; 164/200] END criterion=entropy, max_depth=7, max_features=None, n_estimators=750;, score=0.809 total time=   2.0s
# [CV 1/5; 175/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=1000
# [CV 1/5; 175/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=1000;, score=0.851 total time=   1.8s
# [CV 2/5; 175/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=1000
# [CV 2/5; 175/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=1000;, score=0.808 total time=   1.8s
# [CV 3/5; 191/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100
# [CV 3/5; 191/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100;, score=0.812 total time=   0.2s
# [CV 4/5; 191/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100
# [CV 4/5; 191/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100;, score=0.856 total time=   0.2s
# [CV 4/5; 192/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250
# [CV 4/5; 192/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250;, score=0.851 total time=   0.4s
# [CV 5/5; 192/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250
# [CV 5/5; 192/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250;, score=0.773 total time=   0.4s
# [CV 1/5; 194/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=750
# [CV 1/5; 194/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=750;, score=0.825 total time=   1.3s
# [CV 2/5; 196/200] START criterion=entropy, max_depth=9, max_features=log2, n_estimators=100
# [CV 2/5; 196/200] END criterion=entropy, max_depth=9, max_features=log2, n_estimators=100;, score=0.808 total time=   0.2s
# [CV 2/5; 197/200] START criterion=entropy, max_depth=9, max_features=log2, n_estimators=250
# [CV 2/5; 197/200] END criterion=entropy, max_depth=9, max_features=log2, n_estimators=250;, score=0.818 total time=   0.5s
# [CV 5/5; 198/200] START criterion=entropy, max_depth=9, max_features=log2, n_estimators=500
# [CV 5/5; 198/200] END criterion=entropy, max_depth=9, max_features=log2, n_estimators=500;, score=0.773 total time=   0.9s
# [CV 3/5; 1/200] START criterion=gini, max_depth=1, max_features=None, n_estimators=100
# [CV 3/5; 1/200] END criterion=gini, max_depth=1, max_features=None, n_estimators=100;, score=0.769 total time=   0.1s
# [CV 5/5; 4/200] START criterion=gini, max_depth=1, max_features=None, n_estimators=750
# [CV 5/5; 4/200] END criterion=gini, max_depth=1, max_features=None, n_estimators=750;, score=0.746 total time=   1.1s
# [CV 2/5; 16/200] START criterion=gini, max_depth=1, max_features=log2, n_estimators=100
# [CV 2/5; 16/200] END criterion=gini, max_depth=1, max_features=log2, n_estimators=100;, score=0.810 total time=   0.1s
# [CV 3/5; 16/200] START criterion=gini, max_depth=1, max_features=log2, n_estimators=100
# [CV 3/5; 16/200] END criterion=gini, max_depth=1, max_features=log2, n_estimators=100;, score=0.788 total time=   0.1s
# [CV 3/5; 17/200] START criterion=gini, max_depth=1, max_features=log2, n_estimators=250
# [CV 3/5; 17/200] END criterion=gini, max_depth=1, max_features=log2, n_estimators=250;, score=0.782 total time=   0.3s
# [CV 4/5; 17/200] START criterion=gini, max_depth=1, max_features=log2, n_estimators=250
# [CV 4/5; 17/200] END criterion=gini, max_depth=1, max_features=log2, n_estimators=250;, score=0.821 total time=   0.3s
# [CV 4/5; 22/200] START criterion=gini, max_depth=3, max_features=None, n_estimators=250
# [CV 3/5; 53/200] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=500;, score=0.803 total time=   0.8s
# [CV 5/5; 55/200] START criterion=gini, max_depth=5, max_features=sqrt, n_estimators=1000
# [CV 5/5; 55/200] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=1000;, score=0.763 total time=   1.6s
# [CV 1/5; 56/200] START criterion=gini, max_depth=5, max_features=log2, n_estimators=100
# [CV 1/5; 56/200] END criterion=gini, max_depth=5, max_features=log2, n_estimators=100;, score=0.836 total time=   0.2s
# [CV 4/5; 64/200] START criterion=gini, max_depth=7, max_features=None, n_estimators=750
# [CV 4/5; 64/200] END criterion=gini, max_depth=7, max_features=None, n_estimators=750;, score=0.855 total time=   1.8s
# [CV 5/5; 64/200] START criterion=gini, max_depth=7, max_features=None, n_estimators=750
# [CV 5/5; 64/200] END criterion=gini, max_depth=7, max_features=None, n_estimators=750;, score=0.768 total time=   1.9s
# [CV 3/5; 78/200] START criterion=gini, max_depth=7, max_features=log2, n_estimators=500
# [CV 3/5; 78/200] END criterion=gini, max_depth=7, max_features=log2, n_estimators=500;, score=0.805 total time=   0.9s
# [CV 3/5; 81/200] START criterion=gini, max_depth=9, max_features=None, n_estimators=100
# [CV 3/5; 81/200] END criterion=gini, max_depth=9, max_features=None, n_estimators=100;, score=0.777 total time=   0.3s
# [CV 2/5; 82/200] START criterion=gini, max_depth=9, max_features=None, n_estimators=250
# [CV 2/5; 82/200] END criterion=gini, max_depth=9, max_features=None, n_estimators=250;, score=0.808 total time=   0.6s
# [CV 3/5; 84/200] START criterion=gini, max_depth=9, max_features=None, n_estimators=750
# [CV 3/5; 84/200] END criterion=gini, max_depth=9, max_features=None, n_estimators=750;, score=0.790 total time=   1.9s
# [CV 4/5; 94/200] START criterion=gini, max_depth=9, max_features=sqrt, n_estimators=750
# [CV 4/5; 94/200] END criterion=gini, max_depth=9, max_features=sqrt, n_estimators=750;, score=0.839 total time=   1.3s
# [CV 5/5; 99/200] START criterion=gini, max_depth=9, max_features=log2, n_estimators=750
# [CV 5/5; 99/200] END criterion=gini, max_depth=9, max_features=log2, n_estimators=750;, score=0.769 total time=   1.4s
# [CV 1/5; 100/200] START criterion=gini, max_depth=9, max_features=log2, n_estimators=1000
# [CV 1/5; 100/200] END criterion=gini, max_depth=9, max_features=log2, n_estimators=1000;, score=0.829 total time=   1.9s
# [CV 5/5; 117/200] START criterion=entropy, max_depth=1, max_features=log2, n_estimators=250
# [CV 5/5; 117/200] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=250;, score=0.748 total time=   0.4s
# [CV 1/5; 118/200] START criterion=entropy, max_depth=1, max_features=log2, n_estimators=500
# [CV 1/5; 118/200] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=500;, score=0.852 total time=   0.7s
# [CV 4/5; 122/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=250
# [CV 4/5; 122/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=250;, score=0.830 total time=   0.5s
# [CV 1/5; 124/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=750
# [CV 1/5; 124/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=750;, score=0.861 total time=   1.5s
# [CV 5/5; 132/200] START criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=250
# [CV 5/5; 132/200] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=250;, score=0.748 total time=   0.4s
# [CV 2/5; 134/200] START criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=750
# [CV 2/5; 134/200] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=750;, score=0.805 total time=   1.2s
# [CV 2/5; 140/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=1000
# [CV 2/5; 140/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=1000;, score=0.814 total time=   1.6s
# [CV 3/5; 140/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=1000
# [CV 3/5; 140/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=1000;, score=0.810 total time=   1.6s
# [CV 3/5; 154/200] START criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=750
# [CV 3/5; 154/200] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=750;, score=0.809 total time=   1.3s
# [CV 3/5; 157/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=250
# [CV 3/5; 157/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=250;, score=0.816 total time=   0.5s
# [CV 4/5; 159/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=750
# [CV 4/5; 159/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=750;, score=0.855 total time=   1.4s
# [CV 1/5; 164/200] START criterion=entropy, max_depth=7, max_features=None, n_estimators=750
# [CV 1/5; 164/200] END criterion=entropy, max_depth=7, max_features=None, n_estimators=750;, score=0.848 total time=   2.0s
# [CV 4/5; 174/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=750
# [CV 4/5; 174/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=750;, score=0.851 total time=   1.3s
# [CV 5/5; 174/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=750
# [CV 5/5; 174/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=750;, score=0.772 total time=   1.4s
# [CV 1/5; 185/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=1000
# [CV 1/5; 185/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=1000;, score=0.842 total time=   2.8s
# [CV 2/5; 185/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=1000
# [CV 2/5; 185/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=1000;, score=0.805 total time=   2.5s
# [CV 1/5; 2/200] START criterion=gini, max_depth=1, max_features=None, n_estimators=250
# [CV 1/5; 2/200] END criterion=gini, max_depth=1, max_features=None, n_estimators=250;, score=0.829 total time=   0.3s
# [CV 2/5; 5/200] START criterion=gini, max_depth=1, max_features=None, n_estimators=1000
# [CV 2/5; 5/200] END criterion=gini, max_depth=1, max_features=None, n_estimators=1000;, score=0.801 total time=   1.3s
# [CV 4/5; 18/200] START criterion=gini, max_depth=1, max_features=log2, n_estimators=500
# [CV 4/5; 18/200] END criterion=gini, max_depth=1, max_features=log2, n_estimators=500;, score=0.826 total time=   0.6s
# [CV 5/5; 18/200] START criterion=gini, max_depth=1, max_features=log2, n_estimators=500
# [CV 5/5; 18/200] END criterion=gini, max_depth=1, max_features=log2, n_estimators=500;, score=0.734 total time=   0.6s
# [CV 2/5; 28/200] START criterion=gini, max_depth=3, max_features=auto, n_estimators=500
# [CV 2/5; 28/200] END criterion=gini, max_depth=3, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 3/5; 28/200] START criterion=gini, max_depth=3, max_features=auto, n_estimators=500
# [CV 3/5; 28/200] END criterion=gini, max_depth=3, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 4/5; 28/200] START criterion=gini, max_depth=3, max_features=auto, n_estimators=500
# [CV 4/5; 28/200] END criterion=gini, max_depth=3, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 5/5; 28/200] START criterion=gini, max_depth=3, max_features=auto, n_estimators=500
# [CV 5/5; 28/200] END criterion=gini, max_depth=3, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 5/5; 29/200] START criterion=gini, max_depth=3, max_features=auto, n_estimators=750
# [CV 5/5; 29/200] END criterion=gini, max_depth=3, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 1/5; 30/200] START criterion=gini, max_depth=3, max_features=auto, n_estimators=1000
# [CV 1/5; 30/200] END criterion=gini, max_depth=3, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 2/5; 30/200] START criterion=gini, max_depth=3, max_features=auto, n_estimators=1000
# [CV 2/5; 30/200] END criterion=gini, max_depth=3, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 4/5; 90/200] END criterion=gini, max_depth=9, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 5/5; 90/200] START criterion=gini, max_depth=9, max_features=auto, n_estimators=1000
# [CV 5/5; 90/200] END criterion=gini, max_depth=9, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 1/5; 91/200] START criterion=gini, max_depth=9, max_features=sqrt, n_estimators=100
# [CV 1/5; 91/200] END criterion=gini, max_depth=9, max_features=sqrt, n_estimators=100;, score=0.810 total time=   0.2s
# [CV 2/5; 92/200] START criterion=gini, max_depth=9, max_features=sqrt, n_estimators=250
# [CV 2/5; 92/200] END criterion=gini, max_depth=9, max_features=sqrt, n_estimators=250;, score=0.811 total time=   0.4s
# [CV 3/5; 93/200] START criterion=gini, max_depth=9, max_features=sqrt, n_estimators=500
# [CV 3/5; 93/200] END criterion=gini, max_depth=9, max_features=sqrt, n_estimators=500;, score=0.814 total time=   0.8s
# [CV 3/5; 95/200] START criterion=gini, max_depth=9, max_features=sqrt, n_estimators=1000
# [CV 3/5; 95/200] END criterion=gini, max_depth=9, max_features=sqrt, n_estimators=1000;, score=0.808 total time=   1.8s
# [CV 5/5; 103/200] START criterion=entropy, max_depth=1, max_features=None, n_estimators=500
# [CV 5/5; 103/200] END criterion=entropy, max_depth=1, max_features=None, n_estimators=500;, score=0.750 total time=   0.8s
# [CV 1/5; 104/200] START criterion=entropy, max_depth=1, max_features=None, n_estimators=750
# [CV 1/5; 104/200] END criterion=entropy, max_depth=1, max_features=None, n_estimators=750;, score=0.849 total time=   1.2s
# [CV 3/5; 115/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=1000
# [CV 3/5; 115/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=1000;, score=0.790 total time=   1.5s
# [CV 4/5; 115/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=1000
# [CV 4/5; 115/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=1000;, score=0.834 total time=   1.4s
# [CV 2/5; 125/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=1000
# [CV 2/5; 125/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=1000;, score=0.820 total time=   2.0s
# [CV 3/5; 137/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=250
# [CV 3/5; 137/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=250;, score=0.806 total time=   0.4s
# [CV 4/5; 137/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=250
# [CV 4/5; 137/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=250;, score=0.847 total time=   0.4s
# [CV 1/5; 142/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=250
# [CV 1/5; 142/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=250;, score=0.859 total time=   0.6s
# [CV 3/5; 143/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=500
# [CV 3/5; 143/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=500;, score=0.806 total time=   1.2s
# [CV 5/5; 145/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=1000
# [CV 5/5; 145/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=1000;, score=0.764 total time=   2.4s
# [CV 1/5; 159/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=750
# [CV 1/5; 159/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=750;, score=0.855 total time=   1.4s
# [CV 2/5; 163/200] START criterion=entropy, max_depth=7, max_features=None, n_estimators=500
# [CV 2/5; 163/200] END criterion=entropy, max_depth=7, max_features=None, n_estimators=500;, score=0.811 total time=   1.3s
# [CV 3/5; 171/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=100
# [CV 3/5; 171/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=100;, score=0.825 total time=   0.2s
# [CV 1/5; 172/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=250
# [CV 1/5; 172/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=250;, score=0.836 total time=   0.4s
# [CV 2/5; 173/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=500
# [CV 2/5; 173/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=500;, score=0.807 total time=   0.8s
# [CV 1/5; 177/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=250
# [CV 1/5; 177/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=250;, score=0.853 total time=   0.5s
# [CV 2/5; 177/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=250
# [CV 2/5; 177/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=250;, score=0.808 total time=   0.5s
# [CV 2/5; 180/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=1000
# [CV 2/5; 180/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=1000;, score=0.815 total time=   1.9s
# [CV 3/5; 180/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=1000
# [CV 3/5; 180/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=1000;, score=0.814 total time=   2.0s
# [CV 2/5; 195/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=1000
# [CV 2/5; 195/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=1000;, score=0.806 total time=   1.8s
# [CV 1/5; 200/200] START criterion=entropy, max_depth=9, max_features=log2, n_estimators=1000
# [CV 1/5; 200/200] END criterion=entropy, max_depth=9, max_features=log2, n_estimators=1000;, score=0.839 total time=   1.6s
# [CV 3/5; 3/200] START criterion=gini, max_depth=1, max_features=None, n_estimators=500
# [CV 3/5; 3/200] END criterion=gini, max_depth=1, max_features=None, n_estimators=500;, score=0.765 total time=   0.7s
# [CV 3/5; 13/200] START criterion=gini, max_depth=1, max_features=sqrt, n_estimators=500
# [CV 3/5; 13/200] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=500;, score=0.781 total time=   0.7s
# [CV 4/5; 13/200] START criterion=gini, max_depth=1, max_features=sqrt, n_estimators=500
# [CV 4/5; 13/200] END criterion=gini, max_depth=1, max_features=sqrt, n_estimators=500;, score=0.831 total time=   0.7s
# [CV 5/5; 21/200] START criterion=gini, max_depth=3, max_features=None, n_estimators=100
# [CV 5/5; 21/200] END criterion=gini, max_depth=3, max_features=None, n_estimators=100;, score=0.761 total time=   0.2s
# [CV 1/5; 22/200] START criterion=gini, max_depth=3, max_features=None, n_estimators=250
# [CV 1/5; 22/200] END criterion=gini, max_depth=3, max_features=None, n_estimators=250;, score=0.855 total time=   0.4s
# [CV 2/5; 22/200] START criterion=gini, max_depth=3, max_features=None, n_estimators=250
# [CV 2/5; 22/200] END criterion=gini, max_depth=3, max_features=None, n_estimators=250;, score=0.826 total time=   0.5s
# [CV 3/5; 22/200] START criterion=gini, max_depth=3, max_features=None, n_estimators=250
# [CV 3/5; 22/200] END criterion=gini, max_depth=3, max_features=None, n_estimators=250;, score=0.789 total time=   0.5s
# [CV 1/5; 37/200] START criterion=gini, max_depth=3, max_features=log2, n_estimators=250
# [CV 1/5; 37/200] END criterion=gini, max_depth=3, max_features=log2, n_estimators=250;, score=0.857 total time=   0.4s
# ...
# [CV 5/5; 159/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=750;, score=0.773 total time=   1.4s
# [CV 1/5; 160/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=1000
# [CV 1/5; 160/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=1000;, score=0.857 total time=   1.8s
# [CV 3/5; 172/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=250
# [CV 3/5; 172/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=250;, score=0.819 total time=   0.4s
# [CV 3/5; 173/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=500
# [CV 3/5; 173/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=500;, score=0.817 total time=   0.9s
# [CV 5/5; 177/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=250
# [CV 5/5; 177/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=250;, score=0.769 total time=   0.5s
# [CV 1/5; 178/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=500
# [CV 1/5; 178/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=500;, score=0.853 total time=   1.0s
# [CV 3/5; 181/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=100
# [CV 3/5; 181/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=100;, score=0.801 total time=   0.3s
# [CV 1/5; 182/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=250
# [CV 1/5; 182/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=250;, score=0.843 total time=   0.7s
# [CV 3/5; 183/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=500
# [CV 3/5; 183/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=500;, score=0.805 total time=   1.4s
# [CV 4/5; 191/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100
# [CV 4/5; 191/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100;, score=0.856 total time=   0.2s
# [CV 2/5; 192/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250
# [CV 2/5; 192/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250;, score=0.806 total time=   0.4s
# [CV 3/5; 193/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=500
# [CV 4/5; 90/200] START criterion=gini, max_depth=9, max_features=auto, n_estimators=1000
# [CV 4/5; 90/200] END criterion=gini, max_depth=9, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 5/5; 90/200] START criterion=gini, max_depth=9, max_features=auto, n_estimators=1000
# [CV 5/5; 90/200] END criterion=gini, max_depth=9, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 1/5; 91/200] START criterion=gini, max_depth=9, max_features=sqrt, n_estimators=100
# [CV 1/5; 91/200] END criterion=gini, max_depth=9, max_features=sqrt, n_estimators=100;, score=0.810 total time=   0.2s
# [CV 2/5; 91/200] START criterion=gini, max_depth=9, max_features=sqrt, n_estimators=100
# [CV 2/5; 91/200] END criterion=gini, max_depth=9, max_features=sqrt, n_estimators=100;, score=0.813 total time=   0.2s
# [CV 5/5; 91/200] START criterion=gini, max_depth=9, max_features=sqrt, n_estimators=100
# [CV 5/5; 91/200] END criterion=gini, max_depth=9, max_features=sqrt, n_estimators=100;, score=0.773 total time=   0.2s
# [CV 1/5; 92/200] START criterion=gini, max_depth=9, max_features=sqrt, n_estimators=250
# [CV 1/5; 92/200] END criterion=gini, max_depth=9, max_features=sqrt, n_estimators=250;, score=0.824 total time=   0.4s
# [CV 5/5; 93/200] START criterion=gini, max_depth=9, max_features=sqrt, n_estimators=500
# [CV 5/5; 93/200] END criterion=gini, max_depth=9, max_features=sqrt, n_estimators=500;, score=0.768 total time=   0.9s
# [CV 3/5; 95/200] START criterion=gini, max_depth=9, max_features=sqrt, n_estimators=1000
# [CV 3/5; 95/200] END criterion=gini, max_depth=9, max_features=sqrt, n_estimators=1000;, score=0.808 total time=   1.7s
# [CV 1/5; 100/200] START criterion=gini, max_depth=9, max_features=log2, n_estimators=1000
# [CV 1/5; 100/200] END criterion=gini, max_depth=9, max_features=log2, n_estimators=1000;, score=0.829 total time=   1.9s
# [CV 1/5; 107/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=250
# [CV 1/5; 107/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 3/5; 107/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=250
# [CV 3/5; 107/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 5/5; 107/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=250
# [CV 5/5; 107/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 2/5; 108/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=500
# [CV 2/5; 108/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 4/5; 108/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=500
# [CV 4/5; 108/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 1/5; 109/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=750
# [CV 1/5; 109/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 3/5; 109/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=750
# [CV 3/5; 109/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 5/5; 109/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=750
# [CV 5/5; 109/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 1/5; 110/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000
# [CV 1/5; 110/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 2/5; 110/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000
# [CV 2/5; 110/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 3/5; 110/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000
# [CV 3/5; 110/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 4/5; 110/200] START criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000
# [CV 4/5; 110/200] END criterion=entropy, max_depth=1, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 1/5; 111/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=100
# [CV 1/5; 111/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.842 total time=   0.1s
# [CV 5/5; 111/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=100
# [CV 5/5; 111/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=100;, score=0.730 total time=   0.1s
# [CV 5/5; 112/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=250
# [CV 5/5; 112/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=250;, score=0.728 total time=   0.4s
# [CV 1/5; 115/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=1000
# [CV 1/5; 115/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=1000;, score=0.856 total time=   1.5s
# [CV 3/5; 121/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=100
# [CV 3/5; 121/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=100;, score=0.801 total time=   0.2s
# [CV 4/5; 121/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=100
# [CV 4/5; 121/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=100;, score=0.833 total time=   0.2s
# [CV 2/5; 124/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=750
# [CV 2/5; 124/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=750;, score=0.818 total time=   1.5s
# [CV 3/5; 124/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=750
# [CV 3/5; 124/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=750;, score=0.798 total time=   1.6s
# [CV 3/5; 139/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=750
# [CV 3/5; 139/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=750;, score=0.811 total time=   1.3s
# [CV 4/5; 139/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=750
# [CV 4/5; 139/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=750;, score=0.844 total time=   1.3s
# [CV 4/5; 145/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=1000
# [CV 4/5; 145/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=1000;, score=0.846 total time=   2.4s
# [CV 2/5; 160/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=1000
# [CV 2/5; 160/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=1000;, score=0.817 total time=   1.8s
# [CV 3/5; 160/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=1000
# [CV 3/5; 160/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=1000;, score=0.811 total time=   1.8s
# [CV 4/5; 173/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=500
# [CV 4/5; 173/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=500;, score=0.852 total time=   0.9s
# [CV 3/5; 177/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=250
# [CV 3/5; 177/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=250;, score=0.812 total time=   0.5s
# [CV 4/5; 177/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=250
# [CV 4/5; 177/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=250;, score=0.852 total time=   0.5s
# [CV 5/5; 180/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=1000
# [CV 5/5; 180/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=1000;, score=0.774 total time=   1.9s
# [CV 3/5; 185/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=1000
# /home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 250 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 90 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 160 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.77759181 0.78071374 0.77933911 0.77918982 0.7797886         nan
#         nan        nan        nan        nan 0.79666013 0.79540591
#  0.79834151 0.79955541 0.79872725 0.79955378 0.8007922  0.80182195
#  0.80152228 0.80047074 0.81102103 0.81412117 0.81525553 0.81434456
#  0.81442083        nan        nan        nan        nan        nan
#  0.81152119 0.81247902 0.81467909 0.81292797 0.81338455 0.81717119
#  0.81626131 0.81512368 0.81588646 0.81528277 0.81157241 0.81475973
#  0.81612945 0.81497984 0.81566743        nan        nan        nan
#         nan        nan 0.8116999  0.81259562 0.81546475 0.81591043
#  0.81697505 0.81937016 0.81828157 0.81971341 0.81978097 0.81864226
#  0.80592459 0.81084777 0.81593549 0.8152479  0.8157023         nan
#         nan        nan        nan        nan 0.81241255 0.81678653
#  0.81836766 0.816938   0.81647379 0.81977335 0.81510951 0.81685954
#  0.81815517 0.8185322  0.80145581 0.80851912 0.80981149 0.81040972
#  0.81154953        nan        nan        nan        nan        nan
#  0.81062657 0.81219462 0.81354473 0.81262504 0.81225237 0.80639643
#  0.81087283 0.8109393  0.81162471 0.81162907 0.78949984 0.78983273
#  0.7895565  0.78901602 0.7894666         nan        nan        nan
#         nan        nan 0.79681486 0.79870982 0.80254005 0.80003814
#  0.80057535 0.8017631  0.8052479  0.80578729 0.80609676 0.80686172
#  0.81650539 0.8152588  0.81442301 0.81366895 0.8141179         nan
#         nan        nan        nan        nan 0.81458756 0.81129672
#  0.81645963 0.81653482 0.81562602 0.81324943 0.81878828 0.81954233
#  0.81932113 0.8193985  0.81812684 0.81894737 0.81804075 0.81735317
#  0.81696742        nan        nan        nan        nan        nan
#  0.81976027 0.81852457 0.81882423 0.81829683 0.81860848 0.82145254
#  0.8226294  0.8248894  0.82276779 0.82222622 0.81866133 0.81982565
#  0.81959573 0.81838509 0.81867931        nan        nan        nan
#         nan        nan 0.81853547 0.81758636 0.81877629 0.81914787
#  0.81868476 0.82287349 0.81883077 0.81995968 0.81973957 0.82050125
#  0.81348153 0.81522066 0.81498856 0.81529258 0.81391631        nan
#         nan        nan        nan        nan 0.80968508 0.81221205
#  0.81267081 0.81144819 0.81227198 0.81651956 0.81610657 0.81567506
#  0.81704152 0.8171069 ]
#   warnings.warn(
# Best Parameters:  {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 500}
# Accuracy - Train CV:  0.7522499134648667
# Accuracy - Train :  0.8621973929236499
# Accuracy - Test :  0.7965367965367965

# %% [markdown]
# ***RandomSearch***

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint

# specify parameters and distributions to sample from
param_dist = {'n_estimators':sp_randint(100,1000),
              'criterion': ['gini', 'entropy'],
              'max_features': [None, 'auto', 'sqrt', 'log2'],
              'max_depth': [None, 1, 3, 5, 7, 9]
             }

# run randomized search
n_iter_search = 20
random_search = RandomizedSearchCV(clf_rf, param_distributions=param_dist, cv=kfold, 
                                   n_iter=n_iter_search, verbose=10, n_jobs=-1, random_state=seed)

random_search.fit(X_train, y_train)
# report(random_search.cv_results_)

print ('Best Parameters: ', random_search.best_params_)

results = cross_val_score(random_search.best_estimator_, X_train,y_train, cv=kfold)
print ("Accuracy - Train CV: ", results.mean())
print ("Accuracy - Train : ", metrics.accuracy_score(random_search.best_estimator_.predict(X_train), y_train))
print ("Accuracy - Test : ", metrics.accuracy_score(random_search.best_estimator_.predict(X_test), y_test))
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 3/5; 58/200] END criterion=gini, max_depth=5, max_features=log2, n_estimators=500;, score=0.804 total time=   0.9s
# [CV 2/5; 64/200] START criterion=gini, max_depth=7, max_features=None, n_estimators=750
# [CV 2/5; 64/200] END criterion=gini, max_depth=7, max_features=None, n_estimators=750;, score=0.818 total time=   1.8s
# [CV 4/5; 73/200] START criterion=gini, max_depth=7, max_features=sqrt, n_estimators=500
# [CV 4/5; 73/200] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=500;, score=0.852 total time=   0.8s
# [CV 1/5; 77/200] START criterion=gini, max_depth=7, max_features=log2, n_estimators=250
# [CV 1/5; 77/200] END criterion=gini, max_depth=7, max_features=log2, n_estimators=250;, score=0.842 total time=   0.4s
# [CV 2/5; 77/200] START criterion=gini, max_depth=7, max_features=log2, n_estimators=250
# [CV 2/5; 77/200] END criterion=gini, max_depth=7, max_features=log2, n_estimators=250;, score=0.814 total time=   0.5s
# [CV 5/5; 81/200] START criterion=gini, max_depth=9, max_features=None, n_estimators=100
# [CV 5/5; 81/200] END criterion=gini, max_depth=9, max_features=None, n_estimators=100;, score=0.762 total time=   0.3s
# [CV 1/5; 82/200] START criterion=gini, max_depth=9, max_features=None, n_estimators=250
# [CV 1/5; 82/200] END criterion=gini, max_depth=9, max_features=None, n_estimators=250;, score=0.832 total time=   0.6s
# [CV 5/5; 83/200] START criterion=gini, max_depth=9, max_features=None, n_estimators=500
# [CV 5/5; 83/200] END criterion=gini, max_depth=9, max_features=None, n_estimators=500;, score=0.767 total time=   1.3s
# [CV 1/5; 84/200] START criterion=gini, max_depth=9, max_features=None, n_estimators=750
# [CV 1/5; 84/200] END criterion=gini, max_depth=9, max_features=None, n_estimators=750;, score=0.836 total time=   1.9s
# [CV 1/5; 96/200] START criterion=gini, max_depth=9, max_features=log2, n_estimators=100
# [CV 1/5; 96/200] END criterion=gini, max_depth=9, max_features=log2, n_estimators=100;, score=0.826 total time=   0.2s
# [CV 5/5; 96/200] START criterion=gini, max_depth=9, max_features=log2, n_estimators=100
# [CV 5/5; 96/200] END criterion=gini, max_depth=9, max_features=log2, n_estimators=100;, score=0.759 total time=   0.2s
# [CV 2/5; 98/200] START criterion=gini, max_depth=9, max_features=log2, n_estimators=500
# [CV 2/5; 98/200] END criterion=gini, max_depth=9, max_features=log2, n_estimators=500;, score=0.812 total time=   0.9s
# [CV 4/5; 100/200] START criterion=gini, max_depth=9, max_features=log2, n_estimators=1000
# [CV 4/5; 100/200] END criterion=gini, max_depth=9, max_features=log2, n_estimators=1000;, score=0.842 total time=   1.9s
# [CV 3/5; 112/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=250
# [CV 3/5; 112/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=250;, score=0.786 total time=   0.4s
# [CV 3/5; 114/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=750
# [CV 3/5; 114/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=750;, score=0.789 total time=   1.1s
# [CV 2/5; 120/200] START criterion=entropy, max_depth=1, max_features=log2, n_estimators=1000
# [CV 2/5; 120/200] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=1000;, score=0.807 total time=   1.5s
# [CV 3/5; 120/200] START criterion=entropy, max_depth=1, max_features=log2, n_estimators=1000
# [CV 3/5; 120/200] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=1000;, score=0.797 total time=   1.6s
# [CV 4/5; 136/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=100
# [CV 4/5; 136/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.847 total time=   0.2s
# [CV 5/5; 136/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=100
# [CV 5/5; 136/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.752 total time=   0.2s
# [CV 5/5; 137/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=250
# [CV 5/5; 137/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=250;, score=0.765 total time=   0.5s
# [CV 1/5; 138/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=500
# [CV 1/5; 138/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=500;, score=0.862 total time=   1.0s
# [CV 3/5; 142/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=250
# [CV 3/5; 142/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=250;, score=0.802 total time=   0.7s
# [CV 2/5; 144/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=750
# [CV 2/5; 144/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=750;, score=0.815 total time=   2.0s
# [CV 1/5; 154/200] START criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=750
# [CV 1/5; 154/200] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=750;, score=0.854 total time=   1.3s
# [CV 3/5; 159/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=750
# [CV 3/5; 159/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=750;, score=0.815 total time=   1.4s
# [CV 4/5; 159/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=750
# [CV 4/5; 159/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=750;, score=0.855 total time=   1.7s
# [CV 5/5; 171/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=100
# [CV 5/5; 171/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=100;, score=0.768 total time=   0.2s
# [CV 4/5; 172/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=250
# [CV 4/5; 172/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=250;, score=0.859 total time=   0.4s
# [CV 2/5; 174/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=750
# [CV 2/5; 174/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=750;, score=0.808 total time=   1.3s
# [CV 3/5; 174/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=750
# [CV 3/5; 174/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=750;, score=0.815 total time=   1.4s
# [CV 3/5; 182/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=250
# [CV 3/5; 182/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=250;, score=0.805 total time=   0.7s
# [CV 5/5; 183/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=500
# [CV 5/5; 183/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=500;, score=0.771 total time=   1.6s
# [CV 1/5; 193/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=500
# [CV 1/5; 193/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=500;, score=0.826 total time=   0.9s
# [CV 2/5; 195/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=1000
# [CV 2/5; 195/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=1000;, score=0.806 total time=   2.2s
# [CV 1/5; 1/20] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=753
# [CV 1/5; 1/20] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=753;, score=0.676 total time=   0.9s
# [CV 5/5; 5/20] START criterion=gini, max_depth=3, max_features=sqrt, n_estimators=798
# [CV 5/5; 5/20] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=798;, score=0.692 total time=   1.1s
# [CV 1/5; 12/20] START criterion=entropy, max_depth=5, max_features=None, n_estimators=853
# [CV 1/5; 12/20] END criterion=entropy, max_depth=5, max_features=None, n_estimators=853;, score=0.778 total time=   1.8s
# [CV 2/5; 15/20] START criterion=gini, max_depth=3, max_features=log2, n_estimators=571
# [CV 2/5; 15/20] END criterion=gini, max_depth=3, max_features=log2, n_estimators=571;, score=0.769 total time=   0.9s
# [CV 3/5; 16/20] START criterion=entropy, max_depth=5, max_features=None, n_estimators=933
# [CV 3/5; 16/20] END criterion=entropy, max_depth=5, max_features=None, n_estimators=933;, score=0.720 total time=   2.6s
# [CV 1/5; 173/200] START criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=500
# [CV 1/5; 173/200] END criterion=entropy, max_depth=7, max_features=sqrt, n_estimators=500;, score=0.847 total time=   0.9s
# [CV 2/5; 176/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=100
# [CV 2/5; 176/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=100;, score=0.818 total time=   0.2s
# [CV 3/5; 176/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=100
# [CV 3/5; 176/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=100;, score=0.824 total time=   0.2s
# [CV 2/5; 178/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=500
# [CV 2/5; 178/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=500;, score=0.814 total time=   1.0s
# [CV 3/5; 178/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=500
# [CV 3/5; 178/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=500;, score=0.811 total time=   1.0s
# [CV 1/5; 183/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=500
# [CV 1/5; 183/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=500;, score=0.845 total time=   1.4s
# [CV 3/5; 186/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=100
# [CV 3/5; 186/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5; 187/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=250
# [CV 1/5; 187/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 3/5; 187/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=250
# [CV 3/5; 187/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 5/5; 187/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=250
# [CV 5/5; 187/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 2/5; 188/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=500
# [CV 2/5; 188/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 4/5; 188/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=500
# [CV 4/5; 188/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 1/5; 189/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=750
# [CV 1/5; 189/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 3/5; 189/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=750
# [CV 3/5; 189/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 5/5; 189/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=750
# [CV 5/5; 189/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 1/5; 190/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=1000
# [CV 1/5; 190/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 2/5; 190/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=1000
# [CV 2/5; 190/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 3/5; 190/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=1000
# [CV 3/5; 190/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 4/5; 190/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=1000
# [CV 4/5; 190/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 5/5; 190/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=1000
# [CV 5/5; 190/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 1/5; 191/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100
# [CV 1/5; 191/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100;, score=0.802 total time=   0.2s
# [CV 3/5; 191/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100
# [CV 3/5; 191/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100;, score=0.812 total time=   0.2s
# [CV 3/5; 192/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250
# [CV 3/5; 192/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250;, score=0.808 total time=   0.5s
# [CV 5/5; 193/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=500
# [CV 5/5; 193/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=500;, score=0.778 total time=   0.9s
# [CV 1/5; 196/200] START criterion=entropy, max_depth=9, max_features=log2, n_estimators=100
# [CV 1/5; 196/200] END criterion=entropy, max_depth=9, max_features=log2, n_estimators=100;, score=0.835 total time=   0.3s
# [CV 3/5; 196/200] START criterion=entropy, max_depth=9, max_features=log2, n_estimators=100
# [CV 3/5; 196/200] END criterion=entropy, max_depth=9, max_features=log2, n_estimators=100;, score=0.814 total time=   0.3s
# [CV 3/5; 197/200] START criterion=entropy, max_depth=9, max_features=log2, n_estimators=250
# [CV 3/5; 197/200] END criterion=entropy, max_depth=9, max_features=log2, n_estimators=250;, score=0.805 total time=   0.6s
# [CV 1/5; 200/200] START criterion=entropy, max_depth=9, max_features=log2, n_estimators=1000
# [CV 1/5; 200/200] END criterion=entropy, max_depth=9, max_features=log2, n_estimators=1000;, score=0.839 total time=   1.5s
# [CV 2/5; 3/20] START criterion=entropy, max_depth=None, max_features=None, n_estimators=140
# [CV 2/5; 3/20] END criterion=entropy, max_depth=None, max_features=None, n_estimators=140;, score=0.759 total time=   0.4s
# [CV 4/5; 4/20] START criterion=gini, max_depth=7, max_features=log2, n_estimators=589
# [CV 4/5; 4/20] END criterion=gini, max_depth=7, max_features=log2, n_estimators=589;, score=0.766 total time=   1.0s
# [CV 4/5; 9/20] START criterion=gini, max_depth=None, max_features=None, n_estimators=622
# [CV 4/5; 9/20] END criterion=gini, max_depth=None, max_features=None, n_estimators=622;, score=0.748 total time=   1.4s
# [CV 4/5; 14/20] START criterion=entropy, max_depth=None, max_features=None, n_estimators=746
# [CV 4/5; 14/20] END criterion=entropy, max_depth=None, max_features=None, n_estimators=746;, score=0.766 total time=   2.3s
# [CV 3/5; 18/20] START criterion=entropy, max_depth=3, max_features=None, n_estimators=694
# [CV 3/5; 18/20] END criterion=entropy, max_depth=3, max_features=None, n_estimators=694;, score=0.692 total time=   1.4s
# [CV 3/5; 19/20] START criterion=entropy, max_depth=1, max_features=log2, n_estimators=953
# [CV 3/5; 19/20] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=953;, score=0.692 total time=   0.9s
# [CV 4/5; 3/20] START criterion=entropy, max_depth=None, max_features=None, n_estimators=140
# [CV 4/5; 3/20] END criterion=entropy, max_depth=None, max_features=None, n_estimators=140;, score=0.785 total time=   0.4s
# [CV 1/5; 5/20] START criterion=gini, max_depth=3, max_features=sqrt, n_estimators=798
# [CV 1/5; 5/20] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=798;, score=0.787 total time=   1.1s
# [CV 4/5; 10/20] START criterion=gini, max_depth=None, max_features=auto, n_estimators=756
# [CV 4/5; 10/20] END criterion=gini, max_depth=None, max_features=auto, n_estimators=756;, score=nan total time=   0.0s
# [CV 1/5; 11/20] START criterion=entropy, max_depth=9, max_features=None, n_estimators=377
# [CV 1/5; 11/20] END criterion=entropy, max_depth=9, max_features=None, n_estimators=377;, score=0.769 total time=   1.1s
# [CV 2/5; 54/200] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=750;, score=0.819 total time=   1.2s
# [CV 3/5; 54/200] START criterion=gini, max_depth=5, max_features=sqrt, n_estimators=750
# [CV 3/5; 54/200] END criterion=gini, max_depth=5, max_features=sqrt, n_estimators=750;, score=0.803 total time=   1.2s
# [CV 5/5; 64/200] START criterion=gini, max_depth=7, max_features=None, n_estimators=750
# [CV 5/5; 64/200] END criterion=gini, max_depth=7, max_features=None, n_estimators=750;, score=0.768 total time=   1.8s
# [CV 3/5; 74/200] START criterion=gini, max_depth=7, max_features=sqrt, n_estimators=750
# [CV 3/5; 74/200] END criterion=gini, max_depth=7, max_features=sqrt, n_estimators=750;, score=0.805 total time=   1.3s
# [CV 4/5; 80/200] START criterion=gini, max_depth=7, max_features=log2, n_estimators=1000
# [CV 4/5; 80/200] END criterion=gini, max_depth=7, max_features=log2, n_estimators=1000;, score=0.854 total time=   1.8s
# [CV 5/5; 80/200] START criterion=gini, max_depth=7, max_features=log2, n_estimators=1000
# [CV 5/5; 80/200] END criterion=gini, max_depth=7, max_features=log2, n_estimators=1000;, score=0.772 total time=   1.8s
# [CV 1/5; 95/200] START criterion=gini, max_depth=9, max_features=sqrt, n_estimators=1000
# [CV 1/5; 95/200] END criterion=gini, max_depth=9, max_features=sqrt, n_estimators=1000;, score=0.829 total time=   1.8s
# [CV 5/5; 99/200] START criterion=gini, max_depth=9, max_features=log2, n_estimators=750
# [CV 5/5; 99/200] END criterion=gini, max_depth=9, max_features=log2, n_estimators=750;, score=0.769 total time=   1.4s
# [CV 5/5; 104/200] START criterion=entropy, max_depth=1, max_features=None, n_estimators=750
# [CV 5/5; 104/200] END criterion=entropy, max_depth=1, max_features=None, n_estimators=750;, score=0.750 total time=   1.2s
# [CV 4/5; 114/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=750
# [CV 4/5; 114/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=750;, score=0.832 total time=   1.1s
# [CV 4/5; 120/200] START criterion=entropy, max_depth=1, max_features=log2, n_estimators=1000
# [CV 4/5; 120/200] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=1000;, score=0.828 total time=   1.5s
# [CV 5/5; 120/200] START criterion=entropy, max_depth=1, max_features=log2, n_estimators=1000
# [CV 5/5; 120/200] END criterion=entropy, max_depth=1, max_features=log2, n_estimators=1000;, score=0.750 total time=   1.5s
# [CV 2/5; 136/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=100
# [CV 2/5; 136/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.810 total time=   0.2s
# [CV 3/5; 136/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=100
# [CV 3/5; 136/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.801 total time=   0.2s
# [CV 3/5; 137/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=250
# [CV 3/5; 137/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=250;, score=0.806 total time=   0.4s
# [CV 4/5; 137/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=250
# [CV 4/5; 137/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=250;, score=0.847 total time=   0.4s
# [CV 1/5; 141/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=100
# [CV 1/5; 141/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=100;, score=0.854 total time=   0.3s
# [CV 2/5; 141/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=100
# [CV 2/5; 141/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=100;, score=0.814 total time=   0.3s
# [CV 5/5; 141/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=100
# [CV 5/5; 141/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=100;, score=0.771 total time=   0.3s
# [CV 4/5; 142/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=250
# [CV 4/5; 142/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=250;, score=0.851 total time=   0.6s
# [CV 3/5; 144/200] START criterion=entropy, max_depth=5, max_features=None, n_estimators=750
# [CV 3/5; 144/200] END criterion=entropy, max_depth=5, max_features=None, n_estimators=750;, score=0.803 total time=   1.8s
# [CV 4/5; 153/200] START criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500
# [CV 4/5; 153/200] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=500;, score=0.857 total time=   0.8s
# [CV 4/5; 156/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=100
# [CV 4/5; 156/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=100;, score=0.859 total time=   0.2s
# [CV 5/5; 156/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=100
# [CV 5/5; 156/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=100;, score=0.777 total time=   0.2s
# [CV 1/5; 159/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=750
# [CV 1/5; 159/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=750;, score=0.855 total time=   1.4s
# [CV 2/5; 159/200] START criterion=entropy, max_depth=5, max_features=log2, n_estimators=750
# [CV 2/5; 159/200] END criterion=entropy, max_depth=5, max_features=log2, n_estimators=750;, score=0.817 total time=   1.4s
# [CV 3/5; 165/200] START criterion=entropy, max_depth=7, max_features=None, n_estimators=1000
# [CV 3/5; 165/200] END criterion=entropy, max_depth=7, max_features=None, n_estimators=1000;, score=0.806 total time=   2.7s
# [CV 3/5; 179/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=750
# [CV 3/5; 179/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=750;, score=0.810 total time=   1.4s
# [CV 4/5; 179/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=750
# [CV 4/5; 179/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=750;, score=0.852 total time=   1.4s
# [CV 5/5; 185/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=1000
# [CV 5/5; 185/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=1000;, score=0.770 total time=   2.9s
# [CV 1/5; 199/200] START criterion=entropy, max_depth=9, max_features=log2, n_estimators=750
# [CV 1/5; 199/200] END criterion=entropy, max_depth=9, max_features=log2, n_estimators=750;, score=0.838 total time=   1.5s
# [CV 4/5; 2/20] START criterion=gini, max_depth=None, max_features=sqrt, n_estimators=926
# [CV 4/5; 2/20] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=926;, score=0.757 total time=   1.5s
# [CV 1/5; 9/20] START criterion=gini, max_depth=None, max_features=None, n_estimators=622
# [CV 1/5; 9/20] END criterion=gini, max_depth=None, max_features=None, n_estimators=622;, score=0.731 total time=   1.4s
# [CV 4/5; 13/20] START criterion=gini, max_depth=9, max_features=None, n_estimators=691
# [CV 4/5; 13/20] END criterion=gini, max_depth=9, max_features=None, n_estimators=691;, score=0.738 total time=   1.7s
# [CV 1/5; 16/20] START criterion=entropy, max_depth=5, max_features=None, n_estimators=933
# [CV 1/5; 16/20] END criterion=entropy, max_depth=5, max_features=None, n_estimators=933;, score=0.778 total time=   2.6s
# [CV 2/5; 2/20] START criterion=gini, max_depth=None, max_features=sqrt, n_estimators=926
# [CV 2/5; 2/20] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=926;, score=0.769 total time=   1.5s
# [CV 1/5; 9/20] START criterion=gini, max_depth=None, max_features=None, n_estimators=622
# [CV 1/5; 9/20] END criterion=gini, max_depth=None, max_features=None, n_estimators=622;, score=0.731 total time=   1.5s
# [CV 3/5; 13/20] START criterion=gini, max_depth=9, max_features=None, n_estimators=691
# [CV 3/5; 13/20] END criterion=gini, max_depth=9, max_features=None, n_estimators=691;, score=0.729 total time=   1.8s
# [CV 1/5; 16/20] START criterion=entropy, max_depth=5, max_features=None, n_estimators=933
# [CV 5/5; 115/200] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=1000
# [CV 5/5; 115/200] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=1000;, score=0.735 total time=   1.5s
# [CV 4/5; 124/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=750
# [CV 4/5; 124/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=750;, score=0.827 total time=   1.5s
# [CV 5/5; 124/200] START criterion=entropy, max_depth=3, max_features=None, n_estimators=750
# [CV 5/5; 124/200] END criterion=entropy, max_depth=3, max_features=None, n_estimators=750;, score=0.765 total time=   1.8s
# [CV 2/5; 140/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=1000
# [CV 2/5; 140/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=1000;, score=0.814 total time=   2.1s
# [CV 3/5; 140/200] START criterion=entropy, max_depth=3, max_features=log2, n_estimators=1000
# [CV 3/5; 140/200] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=1000;, score=0.810 total time=   1.7s
# [CV 3/5; 155/200] START criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=1000
# [CV 3/5; 155/200] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=1000;, score=0.811 total time=   1.7s
# [CV 4/5; 155/200] START criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=1000
# [CV 4/5; 155/200] END criterion=entropy, max_depth=5, max_features=sqrt, n_estimators=1000;, score=0.854 total time=   1.6s
# [CV 5/5; 164/200] START criterion=entropy, max_depth=7, max_features=None, n_estimators=750
# [CV 5/5; 164/200] END criterion=entropy, max_depth=7, max_features=None, n_estimators=750;, score=0.774 total time=   2.0s
# [CV 4/5; 176/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=100
# [CV 4/5; 176/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 5/5; 176/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=100
# [CV 5/5; 176/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=100;, score=0.775 total time=   0.2s
# [CV 4/5; 178/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=500
# [CV 4/5; 178/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=500;, score=0.850 total time=   1.0s
# [CV 5/5; 178/200] START criterion=entropy, max_depth=7, max_features=log2, n_estimators=500
# [CV 5/5; 178/200] END criterion=entropy, max_depth=7, max_features=log2, n_estimators=500;, score=0.772 total time=   1.0s
# [CV 2/5; 183/200] START criterion=entropy, max_depth=9, max_features=None, n_estimators=500
# [CV 2/5; 183/200] END criterion=entropy, max_depth=9, max_features=None, n_estimators=500;, score=0.800 total time=   1.4s
# [CV 1/5; 186/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=100
# [CV 1/5; 186/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5; 186/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=100
# [CV 2/5; 186/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5; 186/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=100
# [CV 4/5; 186/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5; 186/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=100
# [CV 5/5; 186/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5; 187/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=250
# [CV 2/5; 187/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 4/5; 187/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=250
# [CV 4/5; 187/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=250;, score=nan total time=   0.0s
# [CV 1/5; 188/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=500
# [CV 1/5; 188/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 3/5; 188/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=500
# [CV 3/5; 188/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 5/5; 188/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=500
# [CV 5/5; 188/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=500;, score=nan total time=   0.0s
# [CV 2/5; 189/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=750
# [CV 2/5; 189/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 4/5; 189/200] START criterion=entropy, max_depth=9, max_features=auto, n_estimators=750
# [CV 4/5; 189/200] END criterion=entropy, max_depth=9, max_features=auto, n_estimators=750;, score=nan total time=   0.0s
# [CV 2/5; 191/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100
# [CV 2/5; 191/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 5/5; 191/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100
# [CV 5/5; 191/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=100;, score=0.774 total time=   0.2s
# [CV 4/5; 192/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250
# [CV 4/5; 192/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=250;, score=0.851 total time=   0.5s
# [CV 4/5; 193/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=500
# [CV 4/5; 193/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=500;, score=0.850 total time=   0.9s
# [CV 5/5; 195/200] START criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=1000
# [CV 5/5; 195/200] END criterion=entropy, max_depth=9, max_features=sqrt, n_estimators=1000;, score=0.777 total time=   1.9s
# [CV 4/5; 1/20] START criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=753
# [CV 4/5; 1/20] END criterion=entropy, max_depth=1, max_features=sqrt, n_estimators=753;, score=0.636 total time=   0.8s
# [CV 3/5; 5/20] START criterion=gini, max_depth=3, max_features=sqrt, n_estimators=798
# [CV 3/5; 5/20] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=798;, score=0.710 total time=   1.1s
# [CV 3/5; 11/20] START criterion=entropy, max_depth=9, max_features=None, n_estimators=377
# [CV 3/5; 11/20] END criterion=entropy, max_depth=9, max_features=None, n_estimators=377;, score=0.738 total time=   0.9s
# [CV 4/5; 12/20] START criterion=entropy, max_depth=5, max_features=None, n_estimators=853
# [CV 4/5; 12/20] END criterion=entropy, max_depth=5, max_features=None, n_estimators=853;, score=0.785 total time=   2.1s
# [CV 3/5; 17/20] START criterion=gini, max_depth=5, max_features=None, n_estimators=984
# [CV 3/5; 17/20] END criterion=gini, max_depth=5, max_features=None, n_estimators=984;, score=0.720 total time=   2.4s
# [CV 5/5; 2/20] START criterion=gini, max_depth=None, max_features=sqrt, n_estimators=926
# [CV 5/5; 2/20] END criterion=gini, max_depth=None, max_features=sqrt, n_estimators=926;, score=0.701 total time=   1.5s
# [CV 5/5; 9/20] START criterion=gini, max_depth=None, max_features=None, n_estimators=622
# [CV 5/5; 9/20] END criterion=gini, max_depth=None, max_features=None, n_estimators=622;, score=0.682 total time=   1.7s
# [CV 1/5; 15/20] START criterion=gini, max_depth=3, max_features=log2, n_estimators=571
# [CV 1/5; 15/20] END criterion=gini, max_depth=3, max_features=log2, n_estimators=571;, score=0.787 total time=   0.9s
# [CV 3/5; 15/20] START criterion=gini, max_depth=3, max_features=log2, n_estimators=571
# [CV 3/5; 15/20] END criterion=gini, max_depth=3, max_features=log2, n_estimators=571;, score=0.692 total time=   0.9s
# [CV 4/5; 17/20] START criterion=gini, max_depth=5, max_features=None, n_estimators=984
# /home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 20 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/kazi/Works/Projects/machine-learning/venv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.65728626 0.74110419 0.74672897 0.74664244 0.73918311        nan
#         nan 0.73918311 0.73175839        nan 0.75039806 0.7522153
#  0.7354794  0.74672897 0.73541018 0.7522153  0.74103496 0.74100035
#  0.70012115        nan]
#   warnings.warn(
# Best Parameters:  {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'n_estimators': 853}
# Accuracy - Train CV:  0.7522152994115612
# Accuracy - Train :  0.8640595903165735
# Accuracy - Test :  0.7878787878787878

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.ensemble import RandomForestClassifier
from bayes_opt import BayesianOptimization, UtilityFunction

# Assuming X_train, y_train are defined somewhere in your script

def rfccv(n_estimators, min_samples_split, max_features):
    return cross_val_score(RandomForestClassifier(n_estimators=int(n_estimators),
                                                  min_samples_split=int(min_samples_split),
                                                  max_features=min(max_features, 0.999),
                                                  random_state=2017),
                           X_train, y_train, scoring='f1', cv=kfold).mean()

# Initialize kfold
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Create BayesianOptimization object
rfcBO = BayesianOptimization(rfccv, {'n_estimators': (100, 1000),
                                     'min_samples_split': (2, 25),
                                     'max_features': (0.1, 0.999)})

# Set Gaussian Process parameters using set_gp_params method
rfcBO.set_gp_params(alpha=1e5)

# Create an instance of UtilityFunction
utility = UtilityFunction(kind="ucb", kappa=2.5, xi=0.0)

# Perform Bayesian Optimization
rfcBO.maximize(init_points=5, n_iter=10, acquisition_function=utility)

# Print the maximum F1 score
print('RFC: %f' % rfcBO.res['max']['max_val'])
# Out:
# |   iter    |  target   | max_fe... | min_sa... | n_esti... |
# -------------------------------------------------------------
# | 1         | 0.6465    | 0.4689    | 22.22     | 781.4     |
# | 2         | 0.6262    | 0.2954    | 10.8      | 406.7     |
# | 3         | 0.6371    | 0.7837    | 10.71     | 354.8     |
# | 4         | 0.5875    | 0.1693    | 12.97     | 706.8     |
# | 5         | 0.6247    | 0.7811    | 3.747     | 843.4     |
# | 6         | 0.6255    | 0.3971    | 8.025     | 100.2     |
# | 7         | 0.632     | 0.6497    | 16.14     | 1e+03     |
# | 8         | 0.6196    | 0.2585    | 4.991     | 100.1     |
# | 9         | 0.6349    | 0.8549    | 20.24     | 999.7     |
# | 10        | 0.6409    | 0.7982    | 24.76     | 781.4     |
# | 11        | 0.6219    | 0.9918    | 23.89     | 100.0     |
# | 12        | 0.5758    | 0.2155    | 20.68     | 1e+03     |
# | 13        | 0.6328    | 0.4184    | 24.84     | 480.7     |
